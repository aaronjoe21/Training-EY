# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: py4j==0.10.9.9 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %% [markdown]
# #Dataset with Spark

# %%
orders_data = [
    ("O001","Hyderabad",1200),
    ("O002","Delhi",800),
    ("O003","Mumbai",1500),
    ("O004","Bangalore",400),
    ("O005","Hyderabad",300),
    ("O006","Delhi",2000),
    ("O007","Mumbai",700),
    ("O008","Bangalore",1800),
    ("O009","Delhi",350),
    ("O010","Hyderabad",900)
]

# %%
orders_col=["order_id", "city", "order_amt"]

# %%
orders_df=spark.createDataFrame(orders_data, orders_col)
orders_df.show()
# Out:
# +--------+---------+---------+
# |order_id|     city|order_amt|
# +--------+---------+---------+
# |    O001|Hyderabad|     1200|
# |    O002|    Delhi|      800|
# |    O003|   Mumbai|     1500|
# |    O004|Bangalore|      400|
# |    O005|Hyderabad|      300|
# |    O006|    Delhi|     2000|
# |    O007|   Mumbai|      700|
# |    O008|Bangalore|     1800|
# |    O009|    Delhi|      350|
# |    O010|Hyderabad|      900|
# +--------+---------+---------+

# %%
city_data = [
    ("Hyderabad","Tier-1"),
    ("Delhi","Tier-1"),
    ("Mumbai","Tier-1"),
    ("Bangalore","Tier-1")
]

# %%
city_cols = ["city","city_category"]

# %%
city_df = spark.createDataFrame(city_data, city_cols)
city_df.show()
# Out:
# +---------+-------------+
# |     city|city_category|
# +---------+-------------+
# |Hyderabad|       Tier-1|
# |    Delhi|       Tier-1|
# |   Mumbai|       Tier-1|
# |Bangalore|       Tier-1|
# +---------+-------------+

# %%
from pyspark.sql.functions import col
filtered_orders = orders_df.filter(col("order_amt") > 500)

# %%
joined_df = filtered_orders.join(
    city_df,
    on="city",
    how="inner"
)

# %%
final_df = joined_df.select(
    "order_id",
    "city",
    "city_category",
    "order_amt"
)

# %%
final_df.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project ['order_id, 'city, 'city_category, 'order_amt]
# +- Project [city#28, order_id#27, order_amt#29L, city_category#41]
#    +- Join Inner, (city#28 = city#40)
#       :- Filter (order_amt#29L > cast(500 as bigint))
#       :  +- LogicalRDD [order_id#27, city#28, order_amt#29L], false
#       +- LogicalRDD [city#40, city_category#41], false
#
# == Analyzed Logical Plan ==
# order_id: string, city: string, city_category: string, order_amt: bigint
# Project [order_id#27, city#28, city_category#41, order_amt#29L]
# +- Project [city#28, order_id#27, order_amt#29L, city_category#41]
#    +- Join Inner, (city#28 = city#40)
#       :- Filter (order_amt#29L > cast(500 as bigint))
#       :  +- LogicalRDD [order_id#27, city#28, order_amt#29L], false
#       +- LogicalRDD [city#40, city_category#41], false
#
# == Optimized Logical Plan ==
# Project [order_id#27, city#28, city_category#41, order_amt#29L]
# +- Join Inner, (city#28 = city#40)
#    :- Filter ((isnotnull(order_amt#29L) AND (order_amt#29L > 500)) AND isnotnull(city#28))
#    :  +- LogicalRDD [order_id#27, city#28, order_amt#29L], false
#    +- Filter isnotnull(city#40)
#       +- LogicalRDD [city#40, city_category#41], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [order_id#27, city#28, city_category#41, order_amt#29L]
#    +- SortMergeJoin [city#28], [city#40], Inner
#       :- Sort [city#28 ASC NULLS FIRST], false, 0
#       :  +- Exchange hashpartitioning(city#28, 200), ENSURE_REQUIREMENTS, [plan_id=179]
#       :     +- Filter ((isnotnull(order_amt#29L) AND (order_amt#29L > 500)) AND isnotnull(city#28))
#       :        +- Scan ExistingRDD[order_id#27,city#28,order_amt#29L]
#       +- Sort [city#40 ASC NULLS FIRST], false, 0
#          +- Exchange hashpartitioning(city#40, 200), ENSURE_REQUIREMENTS, [plan_id=180]
#             +- Filter isnotnull(city#40)
#                +- Scan ExistingRDD[city#40,city_category#41]

# %% [markdown]
# # Broadcast

# %%
from pyspark.sql.functions import broadcast

# %%
broadcast_join_df=filtered_orders.join(
    broadcast(city_df),
    on="city",
    how="inner"
)

final_broadcast_df=broadcast_join_df.select(
    "order_id",
    'city',
    "city_category",
    "order_amt"
)

# %%
final_broadcast_df.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project ['order_id, 'city, 'city_category, 'order_amt]
# +- Project [city#28, order_id#27, order_amt#29L, city_category#41]
#    +- Join Inner, (city#28 = city#40)
#       :- Filter (order_amt#29L > cast(500 as bigint))
#       :  +- LogicalRDD [order_id#27, city#28, order_amt#29L], false
#       +- ResolvedHint (strategy=broadcast)
#          +- LogicalRDD [city#40, city_category#41], false
#
# == Analyzed Logical Plan ==
# order_id: string, city: string, city_category: string, order_amt: bigint
# Project [order_id#27, city#28, city_category#41, order_amt#29L]
# +- Project [city#28, order_id#27, order_amt#29L, city_category#41]
#    +- Join Inner, (city#28 = city#40)
#       :- Filter (order_amt#29L > cast(500 as bigint))
#       :  +- LogicalRDD [order_id#27, city#28, order_amt#29L], false
#       +- ResolvedHint (strategy=broadcast)
#          +- LogicalRDD [city#40, city_category#41], false
#
# == Optimized Logical Plan ==
# Project [order_id#27, city#28, city_category#41, order_amt#29L]
# +- Join Inner, (city#28 = city#40), rightHint=(strategy=broadcast)
#    :- Filter ((isnotnull(order_amt#29L) AND (order_amt#29L > 500)) AND isnotnull(city#28))
#    :  +- LogicalRDD [order_id#27, city#28, order_amt#29L], false
#    +- Filter isnotnull(city#40)
#       +- LogicalRDD [city#40, city_category#41], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [order_id#27, city#28, city_category#41, order_amt#29L]
#    +- BroadcastHashJoin [city#28], [city#40], Inner, BuildRight, false
#       :- Filter ((isnotnull(order_amt#29L) AND (order_amt#29L > 500)) AND isnotnull(city#28))
#       :  +- Scan ExistingRDD[order_id#27,city#28,order_amt#29L]
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=209]
#          +- Filter isnotnull(city#40)
#             +- Scan ExistingRDD[city#40,city_category#41]
