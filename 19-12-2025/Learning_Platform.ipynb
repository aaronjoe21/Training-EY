# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: py4j==0.10.9.9 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("MyApp") \
    .getOrCreate()

# %%
from pyspark.sql import functions as F
from pyspark.sql import types as T

# %% [markdown]
# # Raw Data

# %%
raw_users = [
    ("U001","Amit","28","Hyderabad","AI,ML,Cloud"),
    ("U002","Neha","Thirty","Delhi","Testing"),
    ("U003","Ravi",None,"Bangalore",["Data","Spark"]),
    ("U004","Pooja","29","Mumbai","AI|ML"),
    ("U005","", "31","Chennai",None)
]

# %% [markdown]
# # Schema

# %%
schema = T.StructType([
    T.StructField("user_id", T.StringType(), True),
    T.StructField("name", T.StringType(), True),
    T.StructField("age_raw", T.StringType(), True),
    T.StructField("city", T.StringType(), True),
    T.StructField("skills_raw", T.StringType(), True)
])

# %% [markdown]
# # Clean the Data

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T

def coerce_skills(value):
    if isinstance(value, list):
        return ",".join([str(x) for x in value])
    return value

rows = [(u, n, a if a is not None else None, c, coerce_skills(s))
        for (u, n, a, c, s) in raw_users]

df = spark.createDataFrame(rows, schema=schema)

# %%
df = df.withColumn(
    "age",
    F.when(F.col("age_raw").rlike("^[0-9]+$"), F.col("age_raw").cast("int"))
     .when(F.lower(F.col("age_raw")) == "thirty", F.lit(30))
     .when(F.col("age_raw").isNull(), None)
     .otherwise(None)
)

# %%
df = df.withColumn(
    "skills",
    F.when(
        F.col("skills_raw").isNotNull(),
        F.expr("filter(transform(split(regexp_replace(skills_raw, '\\\\|', ','), ','), x -> lower(trim(x))), x -> x != '')")
    ).otherwise(F.array())
)

# %%
df = df.withColumn(
    "name",
    F.when(F.trim(F.col("name")) == "", F.lit("Unknown")).otherwise(F.col("name"))
)

# %%
clean = df.select("user_id", "name", "age", "city", "skills")

clean.show(truncate=False)
clean.printSchema()
# Out:
# +-------+-------+----+---------+---------------+
# |user_id|name   |age |city     |skills         |
# +-------+-------+----+---------+---------------+
# |U001   |Amit   |28  |Hyderabad|[ai, ml, cloud]|
# |U002   |Neha   |30  |Delhi    |[testing]      |
# |U003   |Ravi   |NULL|Bangalore|[data, spark]  |
# |U004   |Pooja  |29  |Mumbai   |[ai, ml]       |
# |U005   |Unknown|31  |Chennai  |[]             |
# +-------+-------+----+---------+---------------+
#
# root
#  |-- user_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- skills: array (nullable = true)
#  |    |-- element: string (containsNull = false)

# %% [markdown]
# # Dataset 2

# %%
raw_courses = [
    ("C001","PySpark Mastery","Data Engineering","Advanced","₹9999"),
    ("C002","AI for Testers","QA","Beginner","8999"),
    ("C003","ML Foundations","AI","Intermediate",None),
    ("C004","Data Engineering Bootcamp","Data","Advanced","₹14999")
]

# %%
schema = T.StructType([
    T.StructField("course_id", T.StringType(), True),
    T.StructField("course_name", T.StringType(), True),
    T.StructField("domain", T.StringType(), True),
    T.StructField("level", T.StringType(), True),
    T.StructField("price_raw", T.StringType(), True)
])

# %%
df = spark.createDataFrame(raw_courses, schema=schema)

# %%
df = df.withColumn(
    "price",
    F.when(F.col("price_raw").isNotNull(),
           F.regexp_replace(F.col("price_raw"), "[^0-9]", "").cast("int")
    ).otherwise(None)
)

# %%
clean_courses = df.select("course_id", "course_name", "domain", "level", "price")

# %%
clean_courses.show(truncate=False)
clean_courses.printSchema()
# Out:
# +---------+-------------------------+----------------+------------+-----+
# |course_id|course_name              |domain          |level       |price|
# +---------+-------------------------+----------------+------------+-----+
# |C001     |PySpark Mastery          |Data Engineering|Advanced    |9999 |
# |C002     |AI for Testers           |QA              |Beginner    |8999 |
# |C003     |ML Foundations           |AI              |Intermediate|NULL |
# |C004     |Data Engineering Bootcamp|Data            |Advanced    |14999|
# +---------+-------------------------+----------------+------------+-----+
#
# root
#  |-- course_id: string (nullable = true)
#  |-- course_name: string (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- price: integer (nullable = true)

# %% [markdown]
# # Dataset 4

# %%
raw_enrollments = [
    ("U001","C001","2024-01-05"),
    ("U002","C002","05/01/2024"),
    ("U003","C001","2024/01/06"),
    ("U004","C003","invalid_date"),
    ("U001","C004","2024-01-10"),
    ("U005","C002","2024-01-12")
]

# %%
schema = T.StructType([
    T.StructField("user_id", T.StringType(), True),
    T.StructField("course_id", T.StringType(), True),
    T.StructField("date_raw", T.StringType(), True)
])

# %%
df = spark.createDataFrame(raw_enrollments, schema=schema)

# %%
df = df.withColumn("date_str", F.regexp_replace("date_raw", "/", "-"))

# %%
df = df.withColumn(
    "enrollment_date",
    F.when(F.col("date_str").rlike("^[0-9]{4}-[0-9]{2}-[0-9]{2}$"),
           F.to_date("date_str", "yyyy-MM-dd"))
     .when(F.col("date_str").rlike("^[0-9]{2}-[0-9]{2}-[0-9]{4}$"),
           F.to_date("date_str", "dd-MM-yyyy"))
     .otherwise(None)
)

# %%
df = df.withColumn("is_valid_date", F.col("enrollment_date").isNotNull())

# %%
clean_df=df
clean_df.show()
# Out:
# +-------+---------+------------+------------+---------------+-------------+
# |user_id|course_id|    date_raw|    date_str|enrollment_date|is_valid_date|
# +-------+---------+------------+------------+---------------+-------------+
# |   U001|     C001|  2024-01-05|  2024-01-05|     2024-01-05|         true|
# |   U002|     C002|  05/01/2024|  05-01-2024|     2024-01-05|         true|
# |   U003|     C001|  2024/01/06|  2024-01-06|     2024-01-06|         true|
# |   U004|     C003|invalid_date|invalid_date|           NULL|        false|
# |   U001|     C004|  2024-01-10|  2024-01-10|     2024-01-10|         true|
# |   U005|     C002|  2024-01-12|  2024-01-12|     2024-01-12|         true|
# +-------+---------+------------+------------+---------------+-------------+

# %%
clean_df=clean_df.drop("is_valid_date")

# %%
clean_df.show()
# Out:
# +-------+---------+------------+------------+---------------+
# |user_id|course_id|    date_raw|    date_str|enrollment_date|
# +-------+---------+------------+------------+---------------+
# |   U001|     C001|  2024-01-05|  2024-01-05|     2024-01-05|
# |   U002|     C002|  05/01/2024|  05-01-2024|     2024-01-05|
# |   U003|     C001|  2024/01/06|  2024-01-06|     2024-01-06|
# |   U004|     C003|invalid_date|invalid_date|           NULL|
# |   U001|     C004|  2024-01-10|  2024-01-10|     2024-01-10|
# |   U005|     C002|  2024-01-12|  2024-01-12|     2024-01-12|
# +-------+---------+------------+------------+---------------+

# %%
clean_df.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- course_id: string (nullable = true)
#  |-- date_raw: string (nullable = true)
#  |-- date_str: string (nullable = true)
#  |-- enrollment_date: date (nullable = true)

# %% [markdown]
# # Dataset 4

# %%
raw_activity = [
    ("U001","login,watch,logout","{'device':'mobile'}",120),
    ("U002",["login","watch"],"device=laptop",90),
    ("U003","login|logout",None,30),
    ("U004",None,"{'device':'tablet'}",60),
    ("U005","login","{'device':'mobile'}",15)
]

# %%
schema = T.StructType([
    T.StructField("user_id", T.StringType(), True),
    T.StructField("actions_raw", T.StringType(), True),
    T.StructField("metadata_raw", T.StringType(), True),
    T.StructField("duration", T.IntegerType(), True)
])

# %%
def coerce_actions(value):
    if isinstance(value, list):
        return ",".join(value)
    return value

rows = [(u, coerce_actions(a), m, d) for (u,a,m,d) in raw_activity]
df = spark.createDataFrame(rows, schema=schema)

# %%
df = df.withColumn(
    "actions",
    F.when(F.col("actions_raw").isNotNull(),
           F.expr("filter(transform(split(regexp_replace(actions_raw, '\\\\|', ','), ','), x -> lower(trim(x))), x -> x != '')")
    ).otherwise(F.array())
)

# %%
df = df.withColumn(
    "device",
    F.when(F.col("metadata_raw").rlike("mobile"), F.lit("mobile"))
     .when(F.col("metadata_raw").rlike("laptop"), F.lit("laptop"))
     .when(F.col("metadata_raw").rlike("tablet"), F.lit("tablet"))
     .otherwise(None)
)

# %%
clean_activity = df.select("user_id", "actions", "device", "duration")

clean_activity.show(truncate=False)
clean_activity.printSchema()
# Out:
# +-------+----------------------+------+--------+
# |user_id|actions               |device|duration|
# +-------+----------------------+------+--------+
# |U001   |[login, watch, logout]|mobile|120     |
# |U002   |[login, watch]        |laptop|90      |
# |U003   |[login, logout]       |NULL  |30      |
# |U004   |[]                    |tablet|60      |
# |U005   |[login]               |mobile|15      |
# +-------+----------------------+------+--------+
#
# root
#  |-- user_id: string (nullable = true)
#  |-- actions: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- device: string (nullable = true)
#  |-- duration: integer (nullable = true)

# %% [markdown]
# # Join users with enrollments

# %%
users_intersect_enrollments = clean_df.select("user_id").intersect(
    clean.select("user_id")
)

users_with_enrollments = clean_df.join(
    users_intersect_enrollments, on="user_id", how="inner"
)

# %%
users_with_enrollments.show()
# Out:
# +-------+---------+------------+------------+---------------+
# |user_id|course_id|    date_raw|    date_str|enrollment_date|
# +-------+---------+------------+------------+---------------+
# |   U002|     C002|  05/01/2024|  05-01-2024|     2024-01-05|
# |   U003|     C001|  2024/01/06|  2024-01-06|     2024-01-06|
# |   U001|     C001|  2024-01-05|  2024-01-05|     2024-01-05|
# |   U004|     C003|invalid_date|invalid_date|           NULL|
# |   U005|     C002|  2024-01-12|  2024-01-12|     2024-01-12|
# |   U001|     C004|  2024-01-10|  2024-01-10|     2024-01-10|
# +-------+---------+------------+------------+---------------+

# %% [markdown]
# # Broadcast

# %%
from pyspark.sql.functions import broadcast

enrollments_users = clean_df.join(broadcast(clean), "user_id", "left")
enrollments_courses = enrollments_users.join(broadcast(clean_courses), "course_id", "left")

# %%
enrollments_courses.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Join UsingJoin(LeftOuter, [course_id])
# :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37]
# :  +- Join LeftOuter, (user_id#130 = user_id#31)
# :     :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
# :     :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
# :     :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
# :     :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
# :     :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
# :     +- ResolvedHint (strategy=broadcast)
# :        +- Project [user_id#31, name#40, age#36, city#34, skills#37]
# :           +- Project [user_id#31, CASE WHEN (trim(name#32, None) = ) THEN Unknown ELSE name#32 END AS name#40, age_raw#33, city#34, skills_raw#35, age#36, skills#37]
# :              +- Project [user_id#31, name#32, age_raw#33, city#34, skills_raw#35, age#36, CASE WHEN isnotnull(skills_raw#35) THEN filter(transform(split(regexp_replace(skills_raw#35, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#38, None)), lambda x#38, false)), lambdafunction(NOT (lambda x#39 = ), lambda x#39, false)) ELSE cast(array() as array<string>) END AS skills#37]
# :                 +- Project [user_id#31, name#32, age_raw#33, city#34, skills_raw#35, CASE WHEN RLIKE(age_raw#33, ^[0-9]+$) THEN cast(age_raw#33 as int) WHEN (lower(age_raw#33) = thirty) THEN 30 WHEN isnull(age_raw#33) THEN cast(null as int) ELSE cast(null as int) END AS age#36]
# :                    +- LogicalRDD [user_id#31, name#32, age_raw#33, city#34, skills_raw#35], false
# +- ResolvedHint (strategy=broadcast)
#    +- Project [course_id#57, course_name#58, domain#59, level#60, price#62]
#       +- Project [course_id#57, course_name#58, domain#59, level#60, price_raw#61, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) ELSE cast(null as int) END AS price#62]
#          +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Analyzed Logical Plan ==
# course_id: string, user_id: string, date_raw: string, date_str: string, enrollment_date: date, name: string, age: int, city: string, skills: array<string>, course_name: string, domain: string, level: string, price: int
# Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37, course_name#58, domain#59, level#60, price#62]
# +- Join LeftOuter, (course_id#131 = course_id#57)
#    :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37]
#    :  +- Join LeftOuter, (user_id#130 = user_id#31)
#    :     :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
#    :     :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
#    :     :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
#    :     :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#    :     :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#    :     +- ResolvedHint (strategy=broadcast)
#    :        +- Project [user_id#31, name#40, age#36, city#34, skills#37]
#    :           +- Project [user_id#31, CASE WHEN (trim(name#32, None) = ) THEN Unknown ELSE name#32 END AS name#40, age_raw#33, city#34, skills_raw#35, age#36, skills#37]
#    :              +- Project [user_id#31, name#32, age_raw#33, city#34, skills_raw#35, age#36, CASE WHEN isnotnull(skills_raw#35) THEN filter(transform(split(regexp_replace(skills_raw#35, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#38, None)), lambda x#38, false)), lambdafunction(NOT (lambda x#39 = ), lambda x#39, false)) ELSE cast(array() as array<string>) END AS skills#37]
#    :                 +- Project [user_id#31, name#32, age_raw#33, city#34, skills_raw#35, CASE WHEN RLIKE(age_raw#33, ^[0-9]+$) THEN cast(age_raw#33 as int) WHEN (lower(age_raw#33) = thirty) THEN 30 WHEN isnull(age_raw#33) THEN cast(null as int) ELSE cast(null as int) END AS age#36]
#    :                    +- LogicalRDD [user_id#31, name#32, age_raw#33, city#34, skills_raw#35], false
#    +- ResolvedHint (strategy=broadcast)
#       +- Project [course_id#57, course_name#58, domain#59, level#60, price#62]
#          +- Project [course_id#57, course_name#58, domain#59, level#60, price_raw#61, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) ELSE cast(null as int) END AS price#62]
#             +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Optimized Logical Plan ==
# Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37, course_name#58, domain#59, level#60, price#62]
# +- Join LeftOuter, (course_id#131 = course_id#57), rightHint=(strategy=broadcast)
#    :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37]
#    :  +- Join LeftOuter, (user_id#130 = user_id#31), rightHint=(strategy=broadcast)
#    :     :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN cast(gettimestamp(date_str#133, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN cast(gettimestamp(date_str#133, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) END AS enrollment_date#134]
#    :     :  +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#    :     :     +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#    :     +- Project [user_id#31, CASE WHEN (trim(name#32, None) = ) THEN Unknown ELSE name#32 END AS name#40, CASE WHEN RLIKE(age_raw#33, ^[0-9]+$) THEN cast(age_raw#33 as int) WHEN (lower(age_raw#33) = thirty) THEN 30 WHEN isnull(age_raw#33) THEN null END AS age#36, city#34, CASE WHEN isnotnull(skills_raw#35) THEN filter(transform(split(regexp_replace(skills_raw#35, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#38, None)), lambda x#38, false)), lambdafunction(NOT (lambda x#39 = ), lambda x#39, false)) ELSE [] END AS skills#37]
#    :        +- Filter isnotnull(user_id#31)
#    :           +- LogicalRDD [user_id#31, name#32, age_raw#33, city#34, skills_raw#35], false
#    +- Project [course_id#57, course_name#58, domain#59, level#60, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) END AS price#62]
#       +- Filter isnotnull(course_id#57)
#          +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    ResultQueryStage 2
#    +- *(3) Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37, course_name#58, domain#59, level#60, price#62]
#       +- *(3) BroadcastHashJoin [course_id#131], [course_id#57], LeftOuter, BuildRight, false
#          :- *(3) Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37]
#          :  +- *(3) BroadcastHashJoin [user_id#130], [user_id#31], LeftOuter, BuildRight, false
#          :     :- *(3) Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN cast(gettimestamp(date_str#133, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN cast(gettimestamp(date_str#133, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) END AS enrollment_date#134]
#          :     :  +- *(3) Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#          :     :     +- *(3) Scan ExistingRDD[user_id#130,course_id#131,date_raw#132]
#          :     +- BroadcastQueryStage 0
#          :        +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=949]
#          :           +- Project [user_id#31, CASE WHEN (trim(name#32, None) = ) THEN Unknown ELSE name#32 END AS name#40, CASE WHEN RLIKE(age_raw#33, ^[0-9]+$) THEN cast(age_raw#33 as int) WHEN (lower(age_raw#33) = thirty) THEN 30 WHEN isnull(age_raw#33) THEN null END AS age#36, city#34, CASE WHEN isnotnull(skills_raw#35) THEN filter(transform(split(regexp_replace(skills_raw#35, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#38, None)), lambda x#38, false)), lambdafunction(NOT (lambda x#39 = ), lambda x#39, false)) ELSE [] END AS skills#37]
#          :              +- *(1) Filter isnotnull(user_id#31)
#          :                 +- *(1) Scan ExistingRDD[user_id#31,name#32,age_raw#33,city#34,skills_raw#35]
#          +- BroadcastQueryStage 1
#             +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=965]
#                +- *(2) Project [course_id#57, course_name#58, domain#59, level#60, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) END AS price#62]
#                   +- *(2) Filter isnotnull(course_id#57)
#                      +- *(2) Scan ExistingRDD[course_id#57,course_name#58,domain#59,level#60,price_raw#61]
# +- == Initial Plan ==
#    Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37, course_name#58, domain#59, level#60, price#62]
#    +- BroadcastHashJoin [course_id#131], [course_id#57], LeftOuter, BuildRight, false
#       :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, name#40, age#36, city#34, skills#37]
#       :  +- BroadcastHashJoin [user_id#130], [user_id#31], LeftOuter, BuildRight, false
#       :     :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN cast(gettimestamp(date_str#133, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN cast(gettimestamp(date_str#133, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) END AS enrollment_date#134]
#       :     :  +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#       :     :     +- Scan ExistingRDD[user_id#130,course_id#131,date_raw#132]
#       :     +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=933]
#       :        +- Project [user_id#31, CASE WHEN (trim(name#32, None) = ) THEN Unknown ELSE name#32 END AS name#40, CASE WHEN RLIKE(age_raw#33, ^[0-9]+$) THEN cast(age_raw#33 as int) WHEN (lower(age_raw#33) = thirty) THEN 30 WHEN isnull(age_raw#33) THEN null END AS age#36, city#34, CASE WHEN isnotnull(skills_raw#35) THEN filter(transform(split(regexp_replace(skills_raw#35, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#38, None)), lambda x#38, false)), lambdafunction(NOT (lambda x#39 = ), lambda x#39, false)) ELSE [] END AS skills#37]
#       :           +- Filter isnotnull(user_id#31)
#       :              +- Scan ExistingRDD[user_id#31,name#32,age_raw#33,city#34,skills_raw#35]
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=937]
#          +- Project [course_id#57, course_name#58, domain#59, level#60, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) END AS price#62]
#             +- Filter isnotnull(course_id#57)
#                +- Scan ExistingRDD[course_id#57,course_name#58,domain#59,level#60,price_raw#61]

# %% [markdown]
# # Eliminate Orphan Records

# %%
final = (
    enrollments_courses
    .withColumn("is_orphan",
                (F.col("name").isNull()) | (F.col("course_name").isNull()))
    .filter(~F.col("is_orphan"))
)

# %% [markdown]
# # Total Enrollments per Course

# %%
total_enrollments_per_course = clean_df.groupBy("course_id") \
    .agg(F.countDistinct("user_id").alias("total_enrollments"))

# %%
total_enrollments_per_course.show()
# Out:
# +---------+-----------------+
# |course_id|total_enrollments|
# +---------+-----------------+
# |     C003|                1|
# |     C004|                1|
# |     C001|                2|
# |     C002|                2|
# +---------+-----------------+

# %% [markdown]
# # Total Revenue per Course

# %%
total_revenue_per_course = enrollments_courses.groupBy("course_id", "course_name") \
    .agg((F.count("user_id") * F.first("price")).alias("total_revenue"))

# %%
total_revenue_per_course.show()
# Out:
# +---------+--------------------+-------------+
# |course_id|         course_name|total_revenue|
# +---------+--------------------+-------------+
# |     C001|     PySpark Mastery|        19998|
# |     C002|      AI for Testers|        17998|
# |     C003|      ML Foundations|         NULL|
# |     C004|Data Engineering ...|        14999|
# +---------+--------------------+-------------+

# %% [markdown]
# # Average Engagement Time per Course

# %%
enrollments_activity = enrollments_courses.join(clean_activity, "user_id", "left")

avg_engagement_per_course = enrollments_activity.groupBy("course_id", "course_name") \
    .agg(F.avg("duration").alias("avg_engagement_time"))

# %%
avg_engagement_per_course.show()
# Out:
# +---------+--------------------+-------------------+
# |course_id|         course_name|avg_engagement_time|
# +---------+--------------------+-------------------+
# |     C001|     PySpark Mastery|               75.0|
# |     C002|      AI for Testers|               52.5|
# |     C003|      ML Foundations|               60.0|
# |     C004|Data Engineering ...|              120.0|
# +---------+--------------------+-------------------+

# %% [markdown]
# # Total Courses Enrolled per User

# %%
courses_per_user = clean_df.groupBy("user_id") \
    .agg(F.countDistinct("course_id").alias("total_courses_enrolled"))

# %%
courses_per_user.show()
# Out:
# +-------+----------------------+
# |user_id|total_courses_enrolled|
# +-------+----------------------+
# |   U004|                     1|
# |   U005|                     1|
# |   U002|                     1|
# |   U003|                     1|
# |   U001|                     2|
# +-------+----------------------+

# %% [markdown]
# #  Identify Users with Zero Activity

# %%
clean_df.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- course_id: string (nullable = true)
#  |-- date_raw: string (nullable = true)
#  |-- date_str: string (nullable = true)
#  |-- enrollment_date: date (nullable = true)

# %%
users_with_activity = clean_activity.select("user_id").distinct()

# %%
users_with_activity.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)

# %%
users_with_zero_activity = clean.select("user_id", "name") \
    .join(users_with_activity, "user_id", "left_anti")

# %%
users_with_zero_activity.show()
# Out:
# +-------+----+
# |user_id|name|
# +-------+----+
# +-------+----+

# %% [markdown]
# # Rank Users by Total Time Spent

# %%
from pyspark.sql import Window
import pyspark.sql.functions as F

user_time = clean_activity.groupBy("user_id").agg(F.sum("duration").alias("total_time"))

w = Window.orderBy(F.desc("total_time"))

ranked_users = user_time.withColumn("rank", F.rank().over(w))

# %%
ranked_users.show()
# Out:
# +-------+----------+----+
# |user_id|total_time|rank|
# +-------+----------+----+
# |   U001|       120|   1|
# |   U002|        90|   2|
# |   U004|        60|   3|
# |   U003|        30|   4|
# |   U005|        15|   5|
# +-------+----------+----+

# %% [markdown]
# # Running Revenue per Course by Enrollment Date

# %%
enrollments_courses = clean_df.join(clean_courses, "course_id", "left")

enrollments_courses = enrollments_courses.withColumn("revenue", F.col("price"))

w = Window.partitionBy("course_id").orderBy("enrollment_date") \
          .rowsBetween(Window.unboundedPreceding, Window.currentRow)

running_revenue = enrollments_courses.withColumn("running_revenue", F.sum("revenue").over(w))

# %%
running_revenue.show()
# Out:
# +---------+-------+------------+------------+---------------+--------------------+----------------+------------+-----+-------+---------------+
# |course_id|user_id|    date_raw|    date_str|enrollment_date|         course_name|          domain|       level|price|revenue|running_revenue|
# +---------+-------+------------+------------+---------------+--------------------+----------------+------------+-----+-------+---------------+
# |     C001|   U001|  2024-01-05|  2024-01-05|     2024-01-05|     PySpark Mastery|Data Engineering|    Advanced| 9999|   9999|           9999|
# |     C001|   U003|  2024/01/06|  2024-01-06|     2024-01-06|     PySpark Mastery|Data Engineering|    Advanced| 9999|   9999|          19998|
# |     C002|   U002|  05/01/2024|  05-01-2024|     2024-01-05|      AI for Testers|              QA|    Beginner| 8999|   8999|           8999|
# |     C002|   U005|  2024-01-12|  2024-01-12|     2024-01-12|      AI for Testers|              QA|    Beginner| 8999|   8999|          17998|
# |     C003|   U004|invalid_date|invalid_date|           NULL|      ML Foundations|              AI|Intermediate| NULL|   NULL|           NULL|
# |     C004|   U001|  2024-01-10|  2024-01-10|     2024-01-10|Data Engineering ...|            Data|    Advanced|14999|  14999|          14999|
# +---------+-------+------------+------------+---------------+--------------------+----------------+------------+-----+-------+---------------+

# %% [markdown]
# # Identify Top 2 Users per Course by Engagement

# %%
enrollments_activity = clean_df.join(clean_activity, "user_id", "left")

user_course_time = enrollments_activity.groupBy("course_id", "user_id") \
    .agg(F.sum("duration").alias("total_time"))

w = Window.partitionBy("course_id").orderBy(F.desc("total_time"))

top_users_per_course = user_course_time.withColumn("rank", F.rank().over(w)) \
    .filter(F.col("rank") <= 2)

# %% [markdown]
# # Compare GroupBy vs Window Results

# %%
user_course_time.explain(True)


top_users_per_course.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Aggregate ['course_id, 'user_id], ['course_id, 'user_id, 'sum('duration) AS total_time#523]
# +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, actions#198, device#201, duration#177]
#    +- Join LeftOuter, (user_id#130 = user_id#174)
#       :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
#       :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
#       :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
#       :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#       :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#       +- Project [user_id#174, actions#198, device#201, duration#177]
#          +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#198, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#201]
#             +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#199, None)), lambda x#199, false)), lambdafunction(NOT (lambda x#200 = ), lambda x#200, false)) ELSE cast(array() as array<string>) END AS actions#198, device#181]
#                +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#196, None)), lambda x#196, false)), lambdafunction(NOT (lambda x#197 = ), lambda x#197, false)) ELSE cast(array() as array<string>) END AS actions#195, device#181]
#                   +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#178, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#181]
#                      +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#179, None)), lambda x#179, false)), lambdafunction(NOT (lambda x#180 = ), lambda x#180, false)) ELSE cast(array() as array<string>) END AS actions#178]
#                         +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#
# == Analyzed Logical Plan ==
# course_id: string, user_id: string, total_time: bigint
# Aggregate [course_id#131, user_id#130], [course_id#131, user_id#130, sum(duration#177) AS total_time#523L]
# +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, actions#198, device#201, duration#177]
#    +- Join LeftOuter, (user_id#130 = user_id#174)
#       :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
#       :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
#       :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
#       :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#       :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#       +- Project [user_id#174, actions#198, device#201, duration#177]
#          +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#198, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#201]
#             +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#199, None)), lambda x#199, false)), lambdafunction(NOT (lambda x#200 = ), lambda x#200, false)) ELSE cast(array() as array<string>) END AS actions#198, device#181]
#                +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#196, None)), lambda x#196, false)), lambdafunction(NOT (lambda x#197 = ), lambda x#197, false)) ELSE cast(array() as array<string>) END AS actions#195, device#181]
#                   +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#178, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#181]
#                      +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#179, None)), lambda x#179, false)), lambdafunction(NOT (lambda x#180 = ), lambda x#180, false)) ELSE cast(array() as array<string>) END AS actions#178]
#                         +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#
# == Optimized Logical Plan ==
# Aggregate [course_id#131, user_id#130], [course_id#131, user_id#130, sum(duration#177) AS total_time#523L]
# +- Project [user_id#130, course_id#131, duration#177]
#    +- Join LeftOuter, (user_id#130 = user_id#174)
#       :- Project [user_id#130, course_id#131]
#       :  +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#       +- Project [user_id#174, duration#177]
#          +- Filter isnotnull(user_id#174)
#             +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    ResultQueryStage 3
#    +- *(3) HashAggregate(keys=[course_id#131, user_id#130], functions=[sum(duration#177)], output=[course_id#131, user_id#130, total_time#523L])
#       +- *(3) HashAggregate(keys=[course_id#131, user_id#130], functions=[partial_sum(duration#177)], output=[course_id#131, user_id#130, sum#543L])
#          +- *(3) Project [user_id#130, course_id#131, duration#177]
#             +- *(3) BroadcastHashJoin [user_id#130], [user_id#174], LeftOuter, BuildRight, false
#                :- AQEShuffleRead coalesced
#                :  +- ShuffleQueryStage 0
#                :     +- Exchange hashpartitioning(user_id#130, 200), ENSURE_REQUIREMENTS, [plan_id=3518]
#                :        +- *(1) Project [user_id#130, course_id#131]
#                :           +- *(1) Scan ExistingRDD[user_id#130,course_id#131,date_raw#132]
#                +- BroadcastQueryStage 2
#                   +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=3586]
#                      +- AQEShuffleRead local
#                         +- ShuffleQueryStage 1
#                            +- Exchange hashpartitioning(user_id#174, 200), ENSURE_REQUIREMENTS, [plan_id=3533]
#                               +- *(2) Project [user_id#174, duration#177]
#                                  +- *(2) Filter isnotnull(user_id#174)
#                                     +- *(2) Scan ExistingRDD[user_id#174,actions_raw#175,metadata_raw#176,duration#177]
# +- == Initial Plan ==
#    HashAggregate(keys=[course_id#131, user_id#130], functions=[sum(duration#177)], output=[course_id#131, user_id#130, total_time#523L])
#    +- HashAggregate(keys=[course_id#131, user_id#130], functions=[partial_sum(duration#177)], output=[course_id#131, user_id#130, sum#543L])
#       +- Project [user_id#130, course_id#131, duration#177]
#          +- SortMergeJoin [user_id#130], [user_id#174], LeftOuter
#             :- Sort [user_id#130 ASC NULLS FIRST], false, 0
#             :  +- Exchange hashpartitioning(user_id#130, 200), ENSURE_REQUIREMENTS, [plan_id=3503]
#             :     +- Project [user_id#130, course_id#131]
#             :        +- Scan ExistingRDD[user_id#130,course_id#131,date_raw#132]
#             +- Sort [user_id#174 ASC NULLS FIRST], false, 0
#                +- Exchange hashpartitioning(user_id#174, 200), ENSURE_REQUIREMENTS, [plan_id=3504]
#                   +- Project [user_id#174, duration#177]
#                      +- Filter isnotnull(user_id#174)
#                         +- Scan ExistingRDD[user_id#174,actions_raw#175,metadata_raw#176,duration#177]
#
# == Parsed Logical Plan ==
# 'Filter '`<=`('rank, 2)
# +- Project [course_id#131, user_id#130, total_time#523L, rank#533]
#    +- Project [course_id#131, user_id#130, total_time#523L, rank#533, rank#533]
#       +- Window [rank(total_time#523L) windowspecdefinition(course_id#131, total_time#523L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank#533], [course_id#131], [total_time#523L DESC NULLS LAST]
#          +- Project [course_id#131, user_id#130, total_time#523L]
#             +- Aggregate [course_id#131, user_id#130], [course_id#131, user_id#130, sum(duration#177) AS total_time#523L]
#                +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, actions#198, device#201, duration#177]
#                   +- Join LeftOuter, (user_id#130 = user_id#174)
#                      :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
#                      :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
#                      :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
#                      :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#                      :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#                      +- Project [user_id#174, actions#198, device#201, duration#177]
#                         +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#198, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#201]
#                            +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#199, None)), lambda x#199, false)), lambdafunction(NOT (lambda x#200 = ), lambda x#200, false)) ELSE cast(array() as array<string>) END AS actions#198, device#181]
#                               +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#196, None)), lambda x#196, false)), lambdafunction(NOT (lambda x#197 = ), lambda x#197, false)) ELSE cast(array() as array<string>) END AS actions#195, device#181]
#                                  +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#178, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#181]
#                                     +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#179, None)), lambda x#179, false)), lambdafunction(NOT (lambda x#180 = ), lambda x#180, false)) ELSE cast(array() as array<string>) END AS actions#178]
#                                        +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#
# == Analyzed Logical Plan ==
# course_id: string, user_id: string, total_time: bigint, rank: int
# Filter (rank#533 <= 2)
# +- Project [course_id#131, user_id#130, total_time#523L, rank#533]
#    +- Project [course_id#131, user_id#130, total_time#523L, rank#533, rank#533]
#       +- Window [rank(total_time#523L) windowspecdefinition(course_id#131, total_time#523L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank#533], [course_id#131], [total_time#523L DESC NULLS LAST]
#          +- Project [course_id#131, user_id#130, total_time#523L]
#             +- Aggregate [course_id#131, user_id#130], [course_id#131, user_id#130, sum(duration#177) AS total_time#523L]
#                +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, actions#198, device#201, duration#177]
#                   +- Join LeftOuter, (user_id#130 = user_id#174)
#                      :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
#                      :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
#                      :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
#                      :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#                      :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#                      +- Project [user_id#174, actions#198, device#201, duration#177]
#                         +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#198, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#201]
#                            +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#199, None)), lambda x#199, false)), lambdafunction(NOT (lambda x#200 = ), lambda x#200, false)) ELSE cast(array() as array<string>) END AS actions#198, device#181]
#                               +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#196, None)), lambda x#196, false)), lambdafunction(NOT (lambda x#197 = ), lambda x#197, false)) ELSE cast(array() as array<string>) END AS actions#195, device#181]
#                                  +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#178, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#181]
#                                     +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#179, None)), lambda x#179, false)), lambdafunction(NOT (lambda x#180 = ), lambda x#180, false)) ELSE cast(array() as array<string>) END AS actions#178]
#                                        +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#
# == Optimized Logical Plan ==
# Filter (rank#533 <= 2)
# +- Window [rank(total_time#523L) windowspecdefinition(course_id#131, total_time#523L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank#533], [course_id#131], [total_time#523L DESC NULLS LAST]
#    +- WindowGroupLimit [course_id#131], [total_time#523L DESC NULLS LAST], rank(total_time#523L), 2
#       +- Aggregate [course_id#131, user_id#130], [course_id#131, user_id#130, sum(duration#177) AS total_time#523L]
#          +- Project [user_id#130, course_id#131, duration#177]
#             +- Join LeftOuter, (user_id#130 = user_id#174)
#                :- Project [user_id#130, course_id#131]
#                :  +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#                +- Project [user_id#174, duration#177]
#                   +- Filter isnotnull(user_id#174)
#                      +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Filter (rank#533 <= 2)
#    +- Window [rank(total_time#523L) windowspecdefinition(course_id#131, total_time#523L DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank#533], [course_id#131], [total_time#523L DESC NULLS LAST]
#       +- WindowGroupLimit [course_id#131], [total_time#523L DESC NULLS LAST], rank(total_time#523L), 2, Final
#          +- Sort [course_id#131 ASC NULLS FIRST, total_time#523L DESC NULLS LAST], false, 0
#             +- Exchange hashpartitioning(course_id#131, 200), ENSURE_REQUIREMENTS, [plan_id=3689]
#                +- WindowGroupLimit [course_id#131], [total_time#523L DESC NULLS LAST], rank(total_time#523L), 2, Partial
#                   +- Sort [course_id#131 ASC NULLS FIRST, total_time#523L DESC NULLS LAST], false, 0
#                      +- HashAggregate(keys=[course_id#131, user_id#130], functions=[sum(duration#177)], output=[course_id#131, user_id#130, total_time#523L])
#                         +- HashAggregate(keys=[course_id#131, user_id#130], functions=[partial_sum(duration#177)], output=[course_id#131, user_id#130, sum#543L])
#                            +- Project [user_id#130, course_id#131, duration#177]
#                               +- SortMergeJoin [user_id#130], [user_id#174], LeftOuter
#                                  :- Sort [user_id#130 ASC NULLS FIRST], false, 0
#                                  :  +- Exchange hashpartitioning(user_id#130, 200), ENSURE_REQUIREMENTS, [plan_id=3677]
#                                  :     +- Project [user_id#130, course_id#131]
#                                  :        +- Scan ExistingRDD[user_id#130,course_id#131,date_raw#132]
#                                  +- Sort [user_id#174 ASC NULLS FIRST], false, 0
#                                     +- Exchange hashpartitioning(user_id#174, 200), ENSURE_REQUIREMENTS, [plan_id=3678]
#                                        +- Project [user_id#174, duration#177]
#                                           +- Filter isnotnull(user_id#174)
#                                              +- Scan ExistingRDD[user_id#174,actions_raw#175,metadata_raw#176,duration#177]

# %% [markdown]
# # Aggregate Total Time

# %%
from pyspark.sql import functions as F

user_engagement = clean_activity.groupBy("user_id") \
    .agg(F.sum("duration").alias("total_time"))

# %% [markdown]
# # Classify with Built‑in Functions

# %%
user_engagement = user_engagement.withColumn(
    "engagement_level",
    F.when(F.col("total_time") >= 100, "High")
     .when((F.col("total_time") >= 50) & (F.col("total_time") < 100), "Medium")
     .otherwise("Low")
)

# %%
user_engagement.show()
# Out:
# +-------+----------+----------------+
# |user_id|total_time|engagement_level|
# +-------+----------+----------------+
# |   U002|        90|          Medium|
# |   U001|       120|            High|
# |   U004|        60|          Medium|
# |   U005|        15|             Low|
# |   U003|        30|             Low|
# +-------+----------+----------------+

# %% [markdown]
# # Sort courses by total revenue

# %%
from pyspark.sql import functions as F

enrollments_courses = clean_df.join(clean_courses, "course_id", "left")

total_revenue_per_course = (
    enrollments_courses
    .groupBy("course_id", "course_name")
    .agg((F.count("user_id") * F.first("price")).alias("total_revenue"))
    .orderBy(F.desc("total_revenue"))
)

# %% [markdown]
# # Sort users by engagement within each city

# %%
user_time = clean_activity.groupBy("user_id").agg(F.sum("duration").alias("total_time"))


user_time_city = user_time.join(clean.select("user_id", "city"), "user_id", "left")


users_sorted_within_city = user_time_city.orderBy("city", F.desc("total_time"))

# %% [markdown]
# # Set operations

# %%
users_enrolled = clean_df.select("user_id").distinct()

users_active = clean_activity.select("user_id").distinct()

# %%
users_enrolled.show()
users_active.show()
# Out:
# +-------+
# |user_id|
# +-------+
# |   U002|
# |   U003|
# |   U001|
# |   U004|
# |   U005|
# +-------+
#
# +-------+
# |user_id|
# +-------+
# |   U002|
# |   U001|
# |   U004|
# |   U005|
# |   U003|
# +-------+

# %% [markdown]
# # Find users who enrolled but never became active

# %%
enrolled_not_active = users_enrolled.join(users_active, "user_id", "left_anti")

# %%
enrolled_not_active.show()
# Out:
# +-------+
# |user_id|
# +-------+
# +-------+

# %% [markdown]
# # Find users who are both enrolled and active

# %%
enrolled_and_active = users_enrolled.intersect(users_active)

# %%
enrolled_and_active.show()
# Out:
# +-------+
# |user_id|
# +-------+
# |   U004|
# |   U005|
# |   U002|
# |   U003|
# |   U001|
# +-------+

# %% [markdown]
#  # DAG and performance analysis

# %%
total_revenue_per_course.explain(True)

users_sorted_within_city.explain(True)

enrollments_courses.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Sort ['total_revenue DESC NULLS LAST], true
# +- Aggregate [course_id#131, course_name#58], [course_id#131, course_name#58, (count(user_id#130) * cast(first(price#62, false) as bigint)) AS total_revenue#565L]
#    +- Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, course_name#58, domain#59, level#60, price#62]
#       +- Join LeftOuter, (course_id#131 = course_id#57)
#          :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
#          :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
#          :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
#          :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#          :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#          +- Project [course_id#57, course_name#58, domain#59, level#60, price#62]
#             +- Project [course_id#57, course_name#58, domain#59, level#60, price_raw#61, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) ELSE cast(null as int) END AS price#62]
#                +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Analyzed Logical Plan ==
# course_id: string, course_name: string, total_revenue: bigint
# Sort [total_revenue#565L DESC NULLS LAST], true
# +- Aggregate [course_id#131, course_name#58], [course_id#131, course_name#58, (count(user_id#130) * cast(first(price#62, false) as bigint)) AS total_revenue#565L]
#    +- Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, course_name#58, domain#59, level#60, price#62]
#       +- Join LeftOuter, (course_id#131 = course_id#57)
#          :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
#          :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
#          :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
#          :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#          :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#          +- Project [course_id#57, course_name#58, domain#59, level#60, price#62]
#             +- Project [course_id#57, course_name#58, domain#59, level#60, price_raw#61, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) ELSE cast(null as int) END AS price#62]
#                +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Optimized Logical Plan ==
# Sort [total_revenue#565L DESC NULLS LAST], true
# +- Aggregate [course_id#131, course_name#58], [course_id#131, course_name#58, (count(user_id#130) * cast(first(price#62, false) as bigint)) AS total_revenue#565L]
#    +- Project [course_id#131, user_id#130, course_name#58, price#62]
#       +- Join LeftOuter, (course_id#131 = course_id#57)
#          :- Project [user_id#130, course_id#131]
#          :  +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#          +- Project [course_id#57, course_name#58, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) END AS price#62]
#             +- Filter isnotnull(course_id#57)
#                +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [total_revenue#565L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(total_revenue#565L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=4722]
#       +- HashAggregate(keys=[course_id#131, course_name#58], functions=[count(user_id#130), first(price#62, false)], output=[course_id#131, course_name#58, total_revenue#565L])
#          +- HashAggregate(keys=[course_id#131, course_name#58], functions=[partial_count(user_id#130), partial_first(price#62, false)], output=[course_id#131, course_name#58, count#602L, first#603, valueSet#604])
#             +- Project [course_id#131, user_id#130, course_name#58, price#62]
#                +- SortMergeJoin [course_id#131], [course_id#57], LeftOuter
#                   :- Sort [course_id#131 ASC NULLS FIRST], false, 0
#                   :  +- Exchange hashpartitioning(course_id#131, 200), ENSURE_REQUIREMENTS, [plan_id=4713]
#                   :     +- Project [user_id#130, course_id#131]
#                   :        +- Scan ExistingRDD[user_id#130,course_id#131,date_raw#132]
#                   +- Sort [course_id#57 ASC NULLS FIRST], false, 0
#                      +- Exchange hashpartitioning(course_id#57, 200), ENSURE_REQUIREMENTS, [plan_id=4714]
#                         +- Project [course_id#57, course_name#58, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) END AS price#62]
#                            +- Filter isnotnull(course_id#57)
#                               +- Scan ExistingRDD[course_id#57,course_name#58,domain#59,level#60,price_raw#61]
#
# == Parsed Logical Plan ==
# 'Sort ['city ASC NULLS FIRST, 'total_time DESC NULLS LAST], true
# +- Project [user_id#174, total_time#577L, city#34]
#    +- Join LeftOuter, (user_id#174 = user_id#31)
#       :- Aggregate [user_id#174], [user_id#174, sum(duration#177) AS total_time#577L]
#       :  +- Project [user_id#174, actions#198, device#201, duration#177]
#       :     +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#198, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#201]
#       :        +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#199, None)), lambda x#199, false)), lambdafunction(NOT (lambda x#200 = ), lambda x#200, false)) ELSE cast(array() as array<string>) END AS actions#198, device#181]
#       :           +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#196, None)), lambda x#196, false)), lambdafunction(NOT (lambda x#197 = ), lambda x#197, false)) ELSE cast(array() as array<string>) END AS actions#195, device#181]
#       :              +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#178, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#181]
#       :                 +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#179, None)), lambda x#179, false)), lambdafunction(NOT (lambda x#180 = ), lambda x#180, false)) ELSE cast(array() as array<string>) END AS actions#178]
#       :                    +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#       +- Project [user_id#31, city#34]
#          +- Project [user_id#31, name#40, age#36, city#34, skills#37]
#             +- Project [user_id#31, CASE WHEN (trim(name#32, None) = ) THEN Unknown ELSE name#32 END AS name#40, age_raw#33, city#34, skills_raw#35, age#36, skills#37]
#                +- Project [user_id#31, name#32, age_raw#33, city#34, skills_raw#35, age#36, CASE WHEN isnotnull(skills_raw#35) THEN filter(transform(split(regexp_replace(skills_raw#35, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#38, None)), lambda x#38, false)), lambdafunction(NOT (lambda x#39 = ), lambda x#39, false)) ELSE cast(array() as array<string>) END AS skills#37]
#                   +- Project [user_id#31, name#32, age_raw#33, city#34, skills_raw#35, CASE WHEN RLIKE(age_raw#33, ^[0-9]+$) THEN cast(age_raw#33 as int) WHEN (lower(age_raw#33) = thirty) THEN 30 WHEN isnull(age_raw#33) THEN cast(null as int) ELSE cast(null as int) END AS age#36]
#                      +- LogicalRDD [user_id#31, name#32, age_raw#33, city#34, skills_raw#35], false
#
# == Analyzed Logical Plan ==
# user_id: string, total_time: bigint, city: string
# Sort [city#34 ASC NULLS FIRST, total_time#577L DESC NULLS LAST], true
# +- Project [user_id#174, total_time#577L, city#34]
#    +- Join LeftOuter, (user_id#174 = user_id#31)
#       :- Aggregate [user_id#174], [user_id#174, sum(duration#177) AS total_time#577L]
#       :  +- Project [user_id#174, actions#198, device#201, duration#177]
#       :     +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#198, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#201]
#       :        +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#199, None)), lambda x#199, false)), lambdafunction(NOT (lambda x#200 = ), lambda x#200, false)) ELSE cast(array() as array<string>) END AS actions#198, device#181]
#       :           +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#196, None)), lambda x#196, false)), lambdafunction(NOT (lambda x#197 = ), lambda x#197, false)) ELSE cast(array() as array<string>) END AS actions#195, device#181]
#       :              +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, actions#178, CASE WHEN RLIKE(metadata_raw#176, mobile) THEN mobile WHEN RLIKE(metadata_raw#176, laptop) THEN laptop WHEN RLIKE(metadata_raw#176, tablet) THEN tablet ELSE cast(null as string) END AS device#181]
#       :                 +- Project [user_id#174, actions_raw#175, metadata_raw#176, duration#177, CASE WHEN isnotnull(actions_raw#175) THEN filter(transform(split(regexp_replace(actions_raw#175, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#179, None)), lambda x#179, false)), lambdafunction(NOT (lambda x#180 = ), lambda x#180, false)) ELSE cast(array() as array<string>) END AS actions#178]
#       :                    +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#       +- Project [user_id#31, city#34]
#          +- Project [user_id#31, name#40, age#36, city#34, skills#37]
#             +- Project [user_id#31, CASE WHEN (trim(name#32, None) = ) THEN Unknown ELSE name#32 END AS name#40, age_raw#33, city#34, skills_raw#35, age#36, skills#37]
#                +- Project [user_id#31, name#32, age_raw#33, city#34, skills_raw#35, age#36, CASE WHEN isnotnull(skills_raw#35) THEN filter(transform(split(regexp_replace(skills_raw#35, \|, ,, 1), ,, -1), lambdafunction(lower(trim(lambda x#38, None)), lambda x#38, false)), lambdafunction(NOT (lambda x#39 = ), lambda x#39, false)) ELSE cast(array() as array<string>) END AS skills#37]
#                   +- Project [user_id#31, name#32, age_raw#33, city#34, skills_raw#35, CASE WHEN RLIKE(age_raw#33, ^[0-9]+$) THEN cast(age_raw#33 as int) WHEN (lower(age_raw#33) = thirty) THEN 30 WHEN isnull(age_raw#33) THEN cast(null as int) ELSE cast(null as int) END AS age#36]
#                      +- LogicalRDD [user_id#31, name#32, age_raw#33, city#34, skills_raw#35], false
#
# == Optimized Logical Plan ==
# Sort [city#34 ASC NULLS FIRST, total_time#577L DESC NULLS LAST], true
# +- Project [user_id#174, total_time#577L, city#34]
#    +- Join LeftOuter, (user_id#174 = user_id#31)
#       :- Aggregate [user_id#174], [user_id#174, sum(duration#177) AS total_time#577L]
#       :  +- Project [user_id#174, duration#177]
#       :     +- LogicalRDD [user_id#174, actions_raw#175, metadata_raw#176, duration#177], false
#       +- Project [user_id#31, city#34]
#          +- Filter isnotnull(user_id#31)
#             +- LogicalRDD [user_id#31, name#32, age_raw#33, city#34, skills_raw#35], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [city#34 ASC NULLS FIRST, total_time#577L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(city#34 ASC NULLS FIRST, total_time#577L DESC NULLS LAST, 200), ENSURE_REQUIREMENTS, [plan_id=4773]
#       +- Project [user_id#174, total_time#577L, city#34]
#          +- SortMergeJoin [user_id#174], [user_id#31], LeftOuter
#             :- Sort [user_id#174 ASC NULLS FIRST], false, 0
#             :  +- HashAggregate(keys=[user_id#174], functions=[sum(duration#177)], output=[user_id#174, total_time#577L])
#             :     +- Exchange hashpartitioning(user_id#174, 200), ENSURE_REQUIREMENTS, [plan_id=4763]
#             :        +- HashAggregate(keys=[user_id#174], functions=[partial_sum(duration#177)], output=[user_id#174, sum#606L])
#             :           +- Project [user_id#174, duration#177]
#             :              +- Scan ExistingRDD[user_id#174,actions_raw#175,metadata_raw#176,duration#177]
#             +- Sort [user_id#31 ASC NULLS FIRST], false, 0
#                +- Exchange hashpartitioning(user_id#31, 200), ENSURE_REQUIREMENTS, [plan_id=4767]
#                   +- Project [user_id#31, city#34]
#                      +- Filter isnotnull(user_id#31)
#                         +- Scan ExistingRDD[user_id#31,name#32,age_raw#33,city#34,skills_raw#35]
#
# == Parsed Logical Plan ==
# 'Join UsingJoin(LeftOuter, [course_id])
# :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
# :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
# :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
# :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
# :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
# +- Project [course_id#57, course_name#58, domain#59, level#60, price#62]
#    +- Project [course_id#57, course_name#58, domain#59, level#60, price_raw#61, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) ELSE cast(null as int) END AS price#62]
#       +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Analyzed Logical Plan ==
# course_id: string, user_id: string, date_raw: string, date_str: string, enrollment_date: date, course_name: string, domain: string, level: string, price: int
# Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, course_name#58, domain#59, level#60, price#62]
# +- Join LeftOuter, (course_id#131 = course_id#57)
#    :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134]
#    :  +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, enrollment_date#134, isnotnull(enrollment_date#134) AS is_valid_date#135]
#    :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN to_date(date_str#133, Some(yyyy-MM-dd), Some(Etc/UTC), true) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN to_date(date_str#133, Some(dd-MM-yyyy), Some(Etc/UTC), true) ELSE cast(null as date) END AS enrollment_date#134]
#    :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#    :           +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#    +- Project [course_id#57, course_name#58, domain#59, level#60, price#62]
#       +- Project [course_id#57, course_name#58, domain#59, level#60, price_raw#61, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) ELSE cast(null as int) END AS price#62]
#          +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Optimized Logical Plan ==
# Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, course_name#58, domain#59, level#60, price#62]
# +- Join LeftOuter, (course_id#131 = course_id#57)
#    :- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN cast(gettimestamp(date_str#133, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN cast(gettimestamp(date_str#133, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) END AS enrollment_date#134]
#    :  +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#    :     +- LogicalRDD [user_id#130, course_id#131, date_raw#132], false
#    +- Project [course_id#57, course_name#58, domain#59, level#60, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) END AS price#62]
#       +- Filter isnotnull(course_id#57)
#          +- LogicalRDD [course_id#57, course_name#58, domain#59, level#60, price_raw#61], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [course_id#131, user_id#130, date_raw#132, date_str#133, enrollment_date#134, course_name#58, domain#59, level#60, price#62]
#    +- SortMergeJoin [course_id#131], [course_id#57], LeftOuter
#       :- Sort [course_id#131 ASC NULLS FIRST], false, 0
#       :  +- Exchange hashpartitioning(course_id#131, 200), ENSURE_REQUIREMENTS, [plan_id=4808]
#       :     +- Project [user_id#130, course_id#131, date_raw#132, date_str#133, CASE WHEN RLIKE(date_str#133, ^[0-9]{4}-[0-9]{2}-[0-9]{2}$) THEN cast(gettimestamp(date_str#133, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) WHEN RLIKE(date_str#133, ^[0-9]{2}-[0-9]{2}-[0-9]{4}$) THEN cast(gettimestamp(date_str#133, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), true) as date) END AS enrollment_date#134]
#       :        +- Project [user_id#130, course_id#131, date_raw#132, regexp_replace(date_raw#132, /, -, 1) AS date_str#133]
#       :           +- Scan ExistingRDD[user_id#130,course_id#131,date_raw#132]
#       +- Sort [course_id#57 ASC NULLS FIRST], false, 0
#          +- Exchange hashpartitioning(course_id#57, 200), ENSURE_REQUIREMENTS, [plan_id=4809]
#             +- Project [course_id#57, course_name#58, domain#59, level#60, CASE WHEN isnotnull(price_raw#61) THEN cast(regexp_replace(price_raw#61, [^0-9], , 1) as int) END AS price#62]
#                +- Filter isnotnull(course_id#57)
#                   +- Scan ExistingRDD[course_id#57,course_name#58,domain#59,level#60,price_raw#61]
