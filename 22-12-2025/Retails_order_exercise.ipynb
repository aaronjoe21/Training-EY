# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("MyApp") \
    .getOrCreate()

# %% [markdown]
# # Dataset

# %%
raw_orders = [
    ("ORD001","C001","Ravi"," Delhi ","Laptop","Electronics","45000","2024-01-05","Completed"),
    ("ORD002","C002","Sneha","Mumbai"," Mobile ","Electronics","32000","05/01/2024","Completed"),
    ("ORD003","C003","Aman","Bangalore","Laptop","Electronics","55000","2024/01/06","Completed"),
    ("ORD004","C004","Pooja","Delhi","Tablet"," Electronics ","","2024-01-07","Cancelled"),
    ("ORD005","C005","Neha","Chennai","Laptop","Electronics","48000","invalid_date","Completed"),
    ("ORD006","C006","Rahul","Mumbai","Mobile","Electronics",None,"2024-01-08","Completed"),
    ("ORD007","C007","Kiran","Bangalore","Tablet","Electronics","30000","2024-01-08","Completed"),
    ("ORD008","C008","Amit","Delhi","Laptop","electronics","45000","2024-01-09","Completed"),
    ("ORD009","C009","Priya"," Pune","Mobile","Electronics","28000","09-01-2024","Completed"),
    ("ORD010","C010","Suresh","Mumbai","Laptop","Electronics","55000","2024-01-10","Completed"),
    ("ORD010","C010","Suresh","Mumbai","Laptop","Electronics","55000","2024-01-10","Completed"),
    ("ORD011","C011","Meena","Chennai","Tablet","Electronics","31000","2024-01-11","Completed"),
    ("ORD012","C012","Arjun","Delhi","Mobile","Electronics","27000","2024/01/11","Completed"),
    ("ORD013","C013","Nikhil","Bangalore","Laptop","Electronics","60000","2024-01-12","Completed"),
    ("ORD014","C014","Rohit","Mumbai","Mobile","Electronics","invalid_price","2024-01-12","Completed"),
    ("ORD015","C015","Anita","Delhi","Tablet","Electronics","29000","2024-01-13","Completed"),
    ("ORD016","C016","Vikas","Chennai","Laptop","Electronics","52000","2024-01-13","Completed"),
    ("ORD017","C017","Sunita","Mumbai","Mobile","Electronics","33000","2024-01-14","Completed"),
    ("ORD018","C018","Deepak","Bangalore","Laptop","Electronics","58000","2024-01-14","Completed"),
    ("ORD019","C019","Pallavi","Delhi","Mobile","Electronics","26000","2024-01-15","Completed"),
    ("ORD020","C020","Manish","Mumbai","Tablet","Electronics","34000","2024-01-15","Completed")
]

# %%
from datetime import datetime

def parse_date(date_str):
    if not date_str or date_str.strip().lower() == "invalid_date":
        return None
    for fmt in ("%Y-%m-%d", "%d/%m/%Y", "%Y/%m/%d", "%d-%m-%Y"):
        try:
            return datetime.strptime(date_str.strip(), fmt).strftime("%Y-%m-%d")
        except ValueError:
            continue
    return None

# %%
def parse_price(price_str):
    try:
        return int(price_str)
    except (TypeError, ValueError):
        return None

# %%
preprocessed = []
for row in raw_orders:
    order_id, cust_id, cust_name, city, product, category, price, order_date, status = row
    preprocessed.append((
        order_id,
        cust_id,
        cust_name,
        city,
        product,
        category,
        parse_price(price),
        parse_date(order_date),
        status
    ))

# %%
columns = ["OrderID","CustomerID","CustomerName","City","Product","Category","Price","OrderDate","Status"]
df = spark.createDataFrame(preprocessed, columns)

# %%
df.show()
# Out:
# +-------+----------+------------+---------+--------+-------------+-----+----------+---------+
# |OrderID|CustomerID|CustomerName|     City| Product|     Category|Price| OrderDate|   Status|
# +-------+----------+------------+---------+--------+-------------+-----+----------+---------+
# | ORD001|      C001|        Ravi|   Delhi |  Laptop|  Electronics|45000|2024-01-05|Completed|
# | ORD002|      C002|       Sneha|   Mumbai| Mobile |  Electronics|32000|2024-01-05|Completed|
# | ORD003|      C003|        Aman|Bangalore|  Laptop|  Electronics|55000|2024-01-06|Completed|
# | ORD004|      C004|       Pooja|    Delhi|  Tablet| Electronics | NULL|2024-01-07|Cancelled|
# | ORD005|      C005|        Neha|  Chennai|  Laptop|  Electronics|48000|      NULL|Completed|
# | ORD006|      C006|       Rahul|   Mumbai|  Mobile|  Electronics| NULL|2024-01-08|Completed|
# | ORD007|      C007|       Kiran|Bangalore|  Tablet|  Electronics|30000|2024-01-08|Completed|
# | ORD008|      C008|        Amit|    Delhi|  Laptop|  electronics|45000|2024-01-09|Completed|
# | ORD009|      C009|       Priya|     Pune|  Mobile|  Electronics|28000|2024-01-09|Completed|
# | ORD010|      C010|      Suresh|   Mumbai|  Laptop|  Electronics|55000|2024-01-10|Completed|
# | ORD010|      C010|      Suresh|   Mumbai|  Laptop|  Electronics|55000|2024-01-10|Completed|
# | ORD011|      C011|       Meena|  Chennai|  Tablet|  Electronics|31000|2024-01-11|Completed|
# | ORD012|      C012|       Arjun|    Delhi|  Mobile|  Electronics|27000|2024-01-11|Completed|
# | ORD013|      C013|      Nikhil|Bangalore|  Laptop|  Electronics|60000|2024-01-12|Completed|
# | ORD014|      C014|       Rohit|   Mumbai|  Mobile|  Electronics| NULL|2024-01-12|Completed|
# | ORD015|      C015|       Anita|    Delhi|  Tablet|  Electronics|29000|2024-01-13|Completed|
# | ORD016|      C016|       Vikas|  Chennai|  Laptop|  Electronics|52000|2024-01-13|Completed|
# | ORD017|      C017|      Sunita|   Mumbai|  Mobile|  Electronics|33000|2024-01-14|Completed|
# | ORD018|      C018|      Deepak|Bangalore|  Laptop|  Electronics|58000|2024-01-14|Completed|
# | ORD019|      C019|     Pallavi|    Delhi|  Mobile|  Electronics|26000|2024-01-15|Completed|
# +-------+----------+------------+---------+--------+-------------+-----+----------+---------+
# only showing top 20 rows

# %% [markdown]
# #Trim space and normailize data

# %%
from pyspark.sql.functions import col, trim, lower, upper, regexp_replace, when
from pyspark.sql.functions import to_date
from pyspark.sql.types import IntegerType

# %%
df = df.withColumn("City", trim(col("City"))) \
       .withColumn("Product", trim(col("Product"))) \
       .withColumn("Category", upper(trim(col("Category"))))

# %% [markdown]
#  # Standardize Date formats

# %%
df.show()
df.printSchema()
# Out:
# +-------+----------+------------+---------+-------+-----------+-----+----------+---------+
# |OrderID|CustomerID|CustomerName|     City|Product|   Category|Price| OrderDate|   Status|
# +-------+----------+------------+---------+-------+-----------+-----+----------+---------+
# | ORD001|      C001|        Ravi|    Delhi| Laptop|ELECTRONICS|45000|2024-01-05|Completed|
# | ORD002|      C002|       Sneha|   Mumbai| Mobile|ELECTRONICS|32000|2024-01-05|Completed|
# | ORD003|      C003|        Aman|Bangalore| Laptop|ELECTRONICS|55000|2024-01-06|Completed|
# | ORD004|      C004|       Pooja|    Delhi| Tablet|ELECTRONICS| NULL|2024-01-07|Cancelled|
# | ORD005|      C005|        Neha|  Chennai| Laptop|ELECTRONICS|48000|      NULL|Completed|
# | ORD006|      C006|       Rahul|   Mumbai| Mobile|ELECTRONICS| NULL|2024-01-08|Completed|
# | ORD007|      C007|       Kiran|Bangalore| Tablet|ELECTRONICS|30000|2024-01-08|Completed|
# | ORD008|      C008|        Amit|    Delhi| Laptop|ELECTRONICS|45000|2024-01-09|Completed|
# | ORD009|      C009|       Priya|     Pune| Mobile|ELECTRONICS|28000|2024-01-09|Completed|
# | ORD010|      C010|      Suresh|   Mumbai| Laptop|ELECTRONICS|55000|2024-01-10|Completed|
# | ORD010|      C010|      Suresh|   Mumbai| Laptop|ELECTRONICS|55000|2024-01-10|Completed|
# | ORD011|      C011|       Meena|  Chennai| Tablet|ELECTRONICS|31000|2024-01-11|Completed|
# | ORD012|      C012|       Arjun|    Delhi| Mobile|ELECTRONICS|27000|2024-01-11|Completed|
# | ORD013|      C013|      Nikhil|Bangalore| Laptop|ELECTRONICS|60000|2024-01-12|Completed|
# | ORD014|      C014|       Rohit|   Mumbai| Mobile|ELECTRONICS| NULL|2024-01-12|Completed|
# | ORD015|      C015|       Anita|    Delhi| Tablet|ELECTRONICS|29000|2024-01-13|Completed|
# | ORD016|      C016|       Vikas|  Chennai| Laptop|ELECTRONICS|52000|2024-01-13|Completed|
# | ORD017|      C017|      Sunita|   Mumbai| Mobile|ELECTRONICS|33000|2024-01-14|Completed|
# | ORD018|      C018|      Deepak|Bangalore| Laptop|ELECTRONICS|58000|2024-01-14|Completed|
# | ORD019|      C019|     Pallavi|    Delhi| Mobile|ELECTRONICS|26000|2024-01-15|Completed|
# +-------+----------+------------+---------+-------+-----------+-----+----------+---------+
# only showing top 20 rows
# root
#  |-- OrderID: string (nullable = true)
#  |-- CustomerID: string (nullable = true)
#  |-- CustomerName: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Price: long (nullable = true)
#  |-- OrderDate: string (nullable = true)
#  |-- Status: string (nullable = true)

# %% [markdown]
# #CLEANING & TRANSFORMATION TASKS

# %%
df = df.toDF(
    "order_id",
    "customer_id",
    "customer_name",
    "city",
    "product",
    "category",
    "price",
    "order_date",
    "status"
)

# %%
from pyspark.sql.functions import col, round, when

df = df.withColumn("price_with_tax", round(col("price") * 1.18, 2))

# %%
df = df.withColumn(
    "price_category",
    when(col("price") < 30000, "Low")
    .when((col("price") >= 30000) & (col("price") < 50000), "Medium")
    .otherwise("High")
)

# %%
df.show(truncate=False)
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+
# |order_id|customer_id|customer_name|city     |product|category   |price|order_date|status   |price_with_tax|price_category|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+
# |ORD001  |C001       |Ravi         |Delhi    |Laptop |ELECTRONICS|45000|2024-01-05|Completed|53100.0       |Medium        |
# |ORD002  |C002       |Sneha        |Mumbai   |Mobile |ELECTRONICS|32000|2024-01-05|Completed|37760.0       |Medium        |
# |ORD003  |C003       |Aman         |Bangalore|Laptop |ELECTRONICS|55000|2024-01-06|Completed|64900.0       |High          |
# |ORD004  |C004       |Pooja        |Delhi    |Tablet |ELECTRONICS|NULL |2024-01-07|Cancelled|NULL          |High          |
# |ORD005  |C005       |Neha         |Chennai  |Laptop |ELECTRONICS|48000|NULL      |Completed|56640.0       |Medium        |
# |ORD006  |C006       |Rahul        |Mumbai   |Mobile |ELECTRONICS|NULL |2024-01-08|Completed|NULL          |High          |
# |ORD007  |C007       |Kiran        |Bangalore|Tablet |ELECTRONICS|30000|2024-01-08|Completed|35400.0       |Medium        |
# |ORD008  |C008       |Amit         |Delhi    |Laptop |ELECTRONICS|45000|2024-01-09|Completed|53100.0       |Medium        |
# |ORD009  |C009       |Priya        |Pune     |Mobile |ELECTRONICS|28000|2024-01-09|Completed|33040.0       |Low           |
# |ORD010  |C010       |Suresh       |Mumbai   |Laptop |ELECTRONICS|55000|2024-01-10|Completed|64900.0       |High          |
# |ORD010  |C010       |Suresh       |Mumbai   |Laptop |ELECTRONICS|55000|2024-01-10|Completed|64900.0       |High          |
# |ORD011  |C011       |Meena        |Chennai  |Tablet |ELECTRONICS|31000|2024-01-11|Completed|36580.0       |Medium        |
# |ORD012  |C012       |Arjun        |Delhi    |Mobile |ELECTRONICS|27000|2024-01-11|Completed|31860.0       |Low           |
# |ORD013  |C013       |Nikhil       |Bangalore|Laptop |ELECTRONICS|60000|2024-01-12|Completed|70800.0       |High          |
# |ORD014  |C014       |Rohit        |Mumbai   |Mobile |ELECTRONICS|NULL |2024-01-12|Completed|NULL          |High          |
# |ORD015  |C015       |Anita        |Delhi    |Tablet |ELECTRONICS|29000|2024-01-13|Completed|34220.0       |Low           |
# |ORD016  |C016       |Vikas        |Chennai  |Laptop |ELECTRONICS|52000|2024-01-13|Completed|61360.0       |High          |
# |ORD017  |C017       |Sunita       |Mumbai   |Mobile |ELECTRONICS|33000|2024-01-14|Completed|38940.0       |Medium        |
# |ORD018  |C018       |Deepak       |Bangalore|Laptop |ELECTRONICS|58000|2024-01-14|Completed|68440.0       |High          |
# |ORD019  |C019       |Pallavi      |Delhi    |Mobile |ELECTRONICS|26000|2024-01-15|Completed|30680.0       |Low           |
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+
# only showing top 20 rows

# %% [markdown]
# #Create order_year , order_month

# %%
df = df.withColumn("order_year", col("order_date").substr(1,4)) \
       .withColumn("order_month", col("order_date").substr(6,2))

# %%
df.show()
# Out:
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+----------+-----------+
# |order_id|customer_id|customer_name|     city|product|   category|price|order_date|   status|price_with_tax|price_category|order_year|order_month|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+----------+-----------+
# |  ORD001|       C001|         Ravi|    Delhi| Laptop|ELECTRONICS|45000|2024-01-05|Completed|       53100.0|        Medium|      2024|         01|
# |  ORD002|       C002|        Sneha|   Mumbai| Mobile|ELECTRONICS|32000|2024-01-05|Completed|       37760.0|        Medium|      2024|         01|
# |  ORD003|       C003|         Aman|Bangalore| Laptop|ELECTRONICS|55000|2024-01-06|Completed|       64900.0|          High|      2024|         01|
# |  ORD004|       C004|        Pooja|    Delhi| Tablet|ELECTRONICS| NULL|2024-01-07|Cancelled|          NULL|          High|      2024|         01|
# |  ORD005|       C005|         Neha|  Chennai| Laptop|ELECTRONICS|48000|      NULL|Completed|       56640.0|        Medium|      NULL|       NULL|
# |  ORD006|       C006|        Rahul|   Mumbai| Mobile|ELECTRONICS| NULL|2024-01-08|Completed|          NULL|          High|      2024|         01|
# |  ORD007|       C007|        Kiran|Bangalore| Tablet|ELECTRONICS|30000|2024-01-08|Completed|       35400.0|        Medium|      2024|         01|
# |  ORD008|       C008|         Amit|    Delhi| Laptop|ELECTRONICS|45000|2024-01-09|Completed|       53100.0|        Medium|      2024|         01|
# |  ORD009|       C009|        Priya|     Pune| Mobile|ELECTRONICS|28000|2024-01-09|Completed|       33040.0|           Low|      2024|         01|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|ELECTRONICS|55000|2024-01-10|Completed|       64900.0|          High|      2024|         01|
# |  ORD010|       C010|       Suresh|   Mumbai| Laptop|ELECTRONICS|55000|2024-01-10|Completed|       64900.0|          High|      2024|         01|
# |  ORD011|       C011|        Meena|  Chennai| Tablet|ELECTRONICS|31000|2024-01-11|Completed|       36580.0|        Medium|      2024|         01|
# |  ORD012|       C012|        Arjun|    Delhi| Mobile|ELECTRONICS|27000|2024-01-11|Completed|       31860.0|           Low|      2024|         01|
# |  ORD013|       C013|       Nikhil|Bangalore| Laptop|ELECTRONICS|60000|2024-01-12|Completed|       70800.0|          High|      2024|         01|
# |  ORD014|       C014|        Rohit|   Mumbai| Mobile|ELECTRONICS| NULL|2024-01-12|Completed|          NULL|          High|      2024|         01|
# |  ORD015|       C015|        Anita|    Delhi| Tablet|ELECTRONICS|29000|2024-01-13|Completed|       34220.0|           Low|      2024|         01|
# |  ORD016|       C016|        Vikas|  Chennai| Laptop|ELECTRONICS|52000|2024-01-13|Completed|       61360.0|          High|      2024|         01|
# |  ORD017|       C017|       Sunita|   Mumbai| Mobile|ELECTRONICS|33000|2024-01-14|Completed|       38940.0|        Medium|      2024|         01|
# |  ORD018|       C018|       Deepak|Bangalore| Laptop|ELECTRONICS|58000|2024-01-14|Completed|       68440.0|          High|      2024|         01|
# |  ORD019|       C019|      Pallavi|    Delhi| Mobile|ELECTRONICS|26000|2024-01-15|Completed|       30680.0|           Low|      2024|         01|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+----------+-----------+
# only showing top 20 rows

# %% [markdown]
# # Aggregate total revenue per city

# %%
revenue_per_city = df.groupBy("City").agg(sum("Price").alias("total_revenue"))

# %%
revenue_per_city.show()
# Out:
# +---------+-------------+
# |     City|total_revenue|
# +---------+-------------+
# |Bangalore|       203000|
# |  Chennai|       131000|
# |   Mumbai|       209000|
# |     Pune|        28000|
# |    Delhi|       172000|
# +---------+-------------+

# %% [markdown]
# # Aggregate total revenue per product

# %%
revenue_per_product = df.groupBy("Product").agg(sum("Price").alias("total_revenue"))

# %%
revenue_per_product.show()
# Out:
# +-------+-------------+
# |Product|total_revenue|
# +-------+-------------+
# | Laptop|       473000|
# | Mobile|       146000|
# | Tablet|       124000|
# +-------+-------------+

# %% [markdown]
# #Identify top 3 cities by revenue

# %%
from pyspark.sql.functions import desc
top3_cities = revenue_per_city.orderBy(desc("total_revenue")).limit(3)

# %%
top3_cities.show()
# Out:
# +---------+-------------+
# |     City|total_revenue|
# +---------+-------------+
# |   Mumbai|       209000|
# |Bangalore|       203000|
# |    Delhi|       172000|
# +---------+-------------+

# %% [markdown]
# # Identify products with average price above threshold

# %%
from pyspark.sql.functions import avg
threshold = 40000
products_above_threshold = df.groupBy("Product") \
                             .agg(avg("Price").alias("avg_price")) \
                             .filter(col("avg_price") > threshold)

# %% [markdown]
# # Write cleaned data to Parquet

# %%
df.write.mode("overwrite").parquet("cleaned_orders_parquet")

# %% [markdown]
# # Read Parquet back and verify schema

# %%
df_parquet = spark.read.parquet("cleaned_orders_parquet")
df_parquet.printSchema()
df_parquet.show(truncate=False)
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: long (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- price_with_tax: double (nullable = true)
#  |-- price_category: string (nullable = true)
#  |-- order_year: string (nullable = true)
#  |-- order_month: string (nullable = true)
#
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+----------+-----------+
# |order_id|customer_id|customer_name|city     |product|category   |price|order_date|status   |price_with_tax|price_category|order_year|order_month|
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+----------+-----------+
# |ORD010  |C010       |Suresh       |Mumbai   |Laptop |ELECTRONICS|55000|2024-01-10|Completed|64900.0       |High          |2024      |01         |
# |ORD011  |C011       |Meena        |Chennai  |Tablet |ELECTRONICS|31000|2024-01-11|Completed|36580.0       |Medium        |2024      |01         |
# |ORD012  |C012       |Arjun        |Delhi    |Mobile |ELECTRONICS|27000|2024-01-11|Completed|31860.0       |Low           |2024      |01         |
# |ORD013  |C013       |Nikhil       |Bangalore|Laptop |ELECTRONICS|60000|2024-01-12|Completed|70800.0       |High          |2024      |01         |
# |ORD014  |C014       |Rohit        |Mumbai   |Mobile |ELECTRONICS|NULL |2024-01-12|Completed|NULL          |High          |2024      |01         |
# |ORD015  |C015       |Anita        |Delhi    |Tablet |ELECTRONICS|29000|2024-01-13|Completed|34220.0       |Low           |2024      |01         |
# |ORD016  |C016       |Vikas        |Chennai  |Laptop |ELECTRONICS|52000|2024-01-13|Completed|61360.0       |High          |2024      |01         |
# |ORD017  |C017       |Sunita       |Mumbai   |Mobile |ELECTRONICS|33000|2024-01-14|Completed|38940.0       |Medium        |2024      |01         |
# |ORD018  |C018       |Deepak       |Bangalore|Laptop |ELECTRONICS|58000|2024-01-14|Completed|68440.0       |High          |2024      |01         |
# |ORD019  |C019       |Pallavi      |Delhi    |Mobile |ELECTRONICS|26000|2024-01-15|Completed|30680.0       |Low           |2024      |01         |
# |ORD020  |C020       |Manish       |Mumbai   |Tablet |ELECTRONICS|34000|2024-01-15|Completed|40120.0       |Medium        |2024      |01         |
# |ORD001  |C001       |Ravi         |Delhi    |Laptop |ELECTRONICS|45000|2024-01-05|Completed|53100.0       |Medium        |2024      |01         |
# |ORD002  |C002       |Sneha        |Mumbai   |Mobile |ELECTRONICS|32000|2024-01-05|Completed|37760.0       |Medium        |2024      |01         |
# |ORD003  |C003       |Aman         |Bangalore|Laptop |ELECTRONICS|55000|2024-01-06|Completed|64900.0       |High          |2024      |01         |
# |ORD004  |C004       |Pooja        |Delhi    |Tablet |ELECTRONICS|NULL |2024-01-07|Cancelled|NULL          |High          |2024      |01         |
# |ORD005  |C005       |Neha         |Chennai  |Laptop |ELECTRONICS|48000|NULL      |Completed|56640.0       |Medium        |NULL      |NULL       |
# |ORD006  |C006       |Rahul        |Mumbai   |Mobile |ELECTRONICS|NULL |2024-01-08|Completed|NULL          |High          |2024      |01         |
# |ORD007  |C007       |Kiran        |Bangalore|Tablet |ELECTRONICS|30000|2024-01-08|Completed|35400.0       |Medium        |2024      |01         |
# |ORD008  |C008       |Amit         |Delhi    |Laptop |ELECTRONICS|45000|2024-01-09|Completed|53100.0       |Medium        |2024      |01         |
# |ORD009  |C009       |Priya        |Pune     |Mobile |ELECTRONICS|28000|2024-01-09|Completed|33040.0       |Low           |2024      |01         |
# +--------+-----------+-------------+---------+-------+-----------+-----+----------+---------+--------------+--------------+----------+-----------+
# only showing top 20 rows

# %% [markdown]
# #Write the same data to ORC

# %%
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz
# !tar xf spark-3.5.0-bin-hadoop3.tgz
# !pip install -q findspark

import os, findspark
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"
findspark.init()

# %% [markdown]
# # no. of Partitions

# %%
print("Number of partitions:", df.rdd.getNumPartitions())
# Out:
# Number of partitions: 2

# %% [markdown]
# # Repartition before writing

# %%
df_repart = df.repartition(4)

df_repart.write.mode("overwrite").parquet("/content/cleaned_orders_parquet")

df_repart.write.mode("overwrite").orc("/content/cleaned_orders_orc")

# %% [markdown]
# # Compare file counts between Parquet and ORC

# %%
import os

parquet_files = os.listdir("/content/cleaned_orders_parquet")
orc_files = os.listdir("/content/cleaned_orders_orc")

print("Parquet file count:", len(parquet_files))
print("ORC file count:", len(orc_files))
# Out:
# Parquet file count: 10
# ORC file count: 10

# %% [markdown]
# # Run pipeline

# %%
df_repart.explain(True)
# Out:
# == Parsed Logical Plan ==
# Repartition 4, true
# +- Project [order_id#265, customer_id#266, customer_name#267, city#268, product#269, category#270, price#271L, order_date#272, status#273, price_with_tax#274, price_category#275, order_year#312, substr(order_date#272, 6, 2) AS order_month#313]
#    +- Project [order_id#265, customer_id#266, customer_name#267, city#268, product#269, category#270, price#271L, order_date#272, status#273, price_with_tax#274, price_category#275, substr(order_date#272, 1, 4) AS order_year#312]
#       +- Project [order_id#265, customer_id#266, customer_name#267, city#268, product#269, category#270, price#271L, order_date#272, status#273, price_with_tax#274, CASE WHEN (price#271L < cast(30000 as bigint)) THEN Low WHEN ((price#271L >= cast(30000 as bigint)) AND (price#271L < cast(50000 as bigint))) THEN Medium ELSE High END AS price_category#275]
#          +- Project [order_id#265, customer_id#266, customer_name#267, city#268, product#269, category#270, price#271L, order_date#272, status#273, round((cast(price#271L as double) * 1.18), 2) AS price_with_tax#274]
#             +- Project [OrderID#197 AS order_id#265, CustomerID#198 AS customer_id#266, CustomerName#199 AS customer_name#267, City#234 AS city#268, Product#235 AS product#269, Category#236 AS category#270, Price#203L AS price#271L, OrderDate#204 AS order_date#272, Status#205 AS status#273]
#                +- Project [OrderID#197, CustomerID#198, CustomerName#199, City#234, Product#235, upper(trim(Category#202, None)) AS Category#236, Price#203L, OrderDate#204, Status#205]
#                   +- Project [OrderID#197, CustomerID#198, CustomerName#199, City#234, trim(Product#201, None) AS Product#235, Category#202, Price#203L, OrderDate#204, Status#205]
#                      +- Project [OrderID#197, CustomerID#198, CustomerName#199, trim(City#200, None) AS City#234, Product#201, Category#202, Price#203L, OrderDate#204, Status#205]
#                         +- LogicalRDD [OrderID#197, CustomerID#198, CustomerName#199, City#200, Product#201, Category#202, Price#203L, OrderDate#204, Status#205], false
#
# == Analyzed Logical Plan ==
# order_id: string, customer_id: string, customer_name: string, city: string, product: string, category: string, price: bigint, order_date: string, status: string, price_with_tax: double, price_category: string, order_year: string, order_month: string
# Repartition 4, true
# +- Project [order_id#265, customer_id#266, customer_name#267, city#268, product#269, category#270, price#271L, order_date#272, status#273, price_with_tax#274, price_category#275, order_year#312, substr(order_date#272, 6, 2) AS order_month#313]
#    +- Project [order_id#265, customer_id#266, customer_name#267, city#268, product#269, category#270, price#271L, order_date#272, status#273, price_with_tax#274, price_category#275, substr(order_date#272, 1, 4) AS order_year#312]
#       +- Project [order_id#265, customer_id#266, customer_name#267, city#268, product#269, category#270, price#271L, order_date#272, status#273, price_with_tax#274, CASE WHEN (price#271L < cast(30000 as bigint)) THEN Low WHEN ((price#271L >= cast(30000 as bigint)) AND (price#271L < cast(50000 as bigint))) THEN Medium ELSE High END AS price_category#275]
#          +- Project [order_id#265, customer_id#266, customer_name#267, city#268, product#269, category#270, price#271L, order_date#272, status#273, round((cast(price#271L as double) * 1.18), 2) AS price_with_tax#274]
#             +- Project [OrderID#197 AS order_id#265, CustomerID#198 AS customer_id#266, CustomerName#199 AS customer_name#267, City#234 AS city#268, Product#235 AS product#269, Category#236 AS category#270, Price#203L AS price#271L, OrderDate#204 AS order_date#272, Status#205 AS status#273]
#                +- Project [OrderID#197, CustomerID#198, CustomerName#199, City#234, Product#235, upper(trim(Category#202, None)) AS Category#236, Price#203L, OrderDate#204, Status#205]
#                   +- Project [OrderID#197, CustomerID#198, CustomerName#199, City#234, trim(Product#201, None) AS Product#235, Category#202, Price#203L, OrderDate#204, Status#205]
#                      +- Project [OrderID#197, CustomerID#198, CustomerName#199, trim(City#200, None) AS City#234, Product#201, Category#202, Price#203L, OrderDate#204, Status#205]
#                         +- LogicalRDD [OrderID#197, CustomerID#198, CustomerName#199, City#200, Product#201, Category#202, Price#203L, OrderDate#204, Status#205], false
#
# == Optimized Logical Plan ==
# Repartition 4, true
# +- Project [OrderID#197 AS order_id#265, CustomerID#198 AS customer_id#266, CustomerName#199 AS customer_name#267, trim(City#200, None) AS city#268, trim(Product#201, None) AS product#269, upper(trim(Category#202, None)) AS category#270, Price#203L AS price#271L, OrderDate#204 AS order_date#272, Status#205 AS status#273, round((cast(Price#203L as double) * 1.18), 2) AS price_with_tax#274, CASE WHEN (Price#203L < 30000) THEN Low WHEN ((Price#203L >= 30000) AND (Price#203L < 50000)) THEN Medium ELSE High END AS price_category#275, substr(OrderDate#204, 1, 4) AS order_year#312, substr(OrderDate#204, 6, 2) AS order_month#313]
#    +- LogicalRDD [OrderID#197, CustomerID#198, CustomerName#199, City#200, Product#201, Category#202, Price#203L, OrderDate#204, Status#205], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Exchange RoundRobinPartitioning(4), REPARTITION_BY_NUM, [plan_id=600]
#    +- Project [OrderID#197 AS order_id#265, CustomerID#198 AS customer_id#266, CustomerName#199 AS customer_name#267, trim(City#200, None) AS city#268, trim(Product#201, None) AS product#269, upper(trim(Category#202, None)) AS category#270, Price#203L AS price#271L, OrderDate#204 AS order_date#272, Status#205 AS status#273, round((cast(Price#203L as double) * 1.18), 2) AS price_with_tax#274, CASE WHEN (Price#203L < 30000) THEN Low WHEN ((Price#203L >= 30000) AND (Price#203L < 50000)) THEN Medium ELSE High END AS price_category#275, substr(OrderDate#204, 1, 4) AS order_year#312, substr(OrderDate#204, 6, 2) AS order_month#313]
#       +- Scan ExistingRDD[OrderID#197,CustomerID#198,CustomerName#199,City#200,Product#201,Category#202,Price#203L,OrderDate#204,Status#205]
